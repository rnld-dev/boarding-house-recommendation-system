# %%
import pandas as pd

# %%
df = pd.read_csv("D:/New/Training/Algoritma/TA/Ref Code/Final Dokumentasi Code TA/data-mentah/data-mentah.csv")
df.head()
# Out:
#                                                 Link  \
# 0  https://mamikos.com/room/kost-kota-surabaya-ko...
# 1  https://mamikos.com/room/kost-kota-surabaya-ko...
# 2  https://mamikos.com/room/kost-kota-surabaya-ko...
# 3  https://mamikos.com/room/kost-kota-surabaya-ko...
# 4  https://mamikos.com/room/kost-kota-surabaya-ko...
#
#                                                 Nama   Lokasi    Harga  Jenis  \
# 0  Kost Singgahsini Rungkut Asri Utara XI Tipe C ...  Rungkut   880000  Putri
# 1  Kost Singgahsini Rungkut Asri Utara XI Tipe A ...  Rungkut  1275000  Putri
# 2  Kost Singgahsini Rungkut Asri Utara XI Tipe B ...  Rungkut   925000  Putri
# 3  Kost Singgahsini Rabbani Syariah Tipe A Rungku...  Rungkut  2525000  Putri
# 4  Kost Singgahsini Rabbani Syariah Tipe C Rungku...  Rungkut  2025000  Putri
#
#                   Listrik  Luas Kamar K Mandi Dalam   AC WiFi Kasur  \
# 0  Tidak termasuk listrik         5.0            No   No  Yes   Yes
# 1  Tidak termasuk listrik         5.0            No  Yes  Yes   Yes
# 2  Tidak termasuk listrik         6.0            No   No  Yes   Yes
# 3  Tidak termasuk listrik        20.0           Yes  Yes  Yes   Yes
# 4  Tidak termasuk listrik        16.0           Yes  Yes  Yes   Yes
#
#   Akses 24 Jam  Panjang Kamar  Lebar Kamar  \
# 0          Yes            2.0          2.5
# 1          Yes            2.0          2.5
# 2          Yes            2.0          3.0
# 3          Yes            5.0          4.0
# 4          Yes            4.0          4.0
#
#                                                 Maps
# 0  https://maps.google.com/maps?z=7&q=-7.3232453,...
# 1  https://maps.google.com/maps?z=7&q=-7.3232453,...
# 2  https://maps.google.com/maps?z=7&q=-7.3232453,...
# 3  https://maps.google.com/maps?z=7&q=-7.319905,1...
# 4  https://maps.google.com/maps?z=7&q=-7.319905,1...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 677 entries, 0 to 676
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Link           677 non-null    object
#  1   Nama           677 non-null    object
#  2   Lokasi         677 non-null    object
#  3   Harga          677 non-null    int64
#  4   Jenis          677 non-null    object
#  5   Listrik        677 non-null    object
#  6   Luas Kamar     676 non-null    float64
#  7   K Mandi Dalam  677 non-null    object
#  8   AC             677 non-null    object
#  9   WiFi           677 non-null    object
#  10  Kasur          677 non-null    object
#  11  Akses 24 Jam   677 non-null    object
#  12  Panjang Kamar  676 non-null    float64
#  13  Lebar Kamar    677 non-null    float64
#  14  Maps           677 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 79.5+ KB

# %%
# Misalkan df adalah DataFrame kamu
df["Link"].nunique()
# Out:
# 677

# %%
df.shape
# Out:
# (677, 15)

# %%
df["Lokasi"].value_counts()
# Out:
# Sukolilo            128
# Gubeng              126
# Rungkut              87
# Mulyorejo            52
# Gunung Anyar         46
# Wonokromo            41
# Tambaksari           35
# Gayungan             28
# Wonocolo             23
# Jambangan            22
# Genteng              18
# Dukuh Pakis          18
# Wiyung               14
# Tegalsari            12
# Lakarsantri           9
# Waru                  7
# Karang Pilang         5
# Tenggilis Mejoyo      4
# Sambikerep            2
# Name: Lokasi, dtype: int64

# %% [markdown]
# `Pemecahan data Maps dari Link Maps menjadi informasi Latitude dan Longitude`

# %%
import re

# Fungsi untuk mengekstrak latitude dan longitude dari URL
def extract_lat_long(url):
    # Fungsi re.search mencari pola di dalam string url
    match = re.search(r'q=(-?\d+\.\d+),(-?\d+\.\d+)', url)
    if match:
        return float(match.group(1)), float(match.group(2))
    else:
        return None, None

# Menerapkan fungsi ke kolom 'Maps' dan membuat kolom 'Latitude' dan 'Longitude'
df[['Latitude', 'Longitude']] = df['Maps'].apply(lambda x: pd.Series(extract_lat_long(x)))

# %%
df.head()
# Out:
#                                                 Link  \
# 0  https://mamikos.com/room/kost-kota-surabaya-ko...
# 1  https://mamikos.com/room/kost-kota-surabaya-ko...
# 2  https://mamikos.com/room/kost-kota-surabaya-ko...
# 3  https://mamikos.com/room/kost-kota-surabaya-ko...
# 4  https://mamikos.com/room/kost-kota-surabaya-ko...
#
#                                                 Nama   Lokasi    Harga  Jenis  \
# 0  Kost Singgahsini Rungkut Asri Utara XI Tipe C ...  Rungkut   880000  Putri
# 1  Kost Singgahsini Rungkut Asri Utara XI Tipe A ...  Rungkut  1275000  Putri
# 2  Kost Singgahsini Rungkut Asri Utara XI Tipe B ...  Rungkut   925000  Putri
# 3  Kost Singgahsini Rabbani Syariah Tipe A Rungku...  Rungkut  2525000  Putri
# 4  Kost Singgahsini Rabbani Syariah Tipe C Rungku...  Rungkut  2025000  Putri
#
#                   Listrik  Luas Kamar K Mandi Dalam   AC WiFi Kasur  \
# 0  Tidak termasuk listrik         5.0            No   No  Yes   Yes
# 1  Tidak termasuk listrik         5.0            No  Yes  Yes   Yes
# 2  Tidak termasuk listrik         6.0            No   No  Yes   Yes
# 3  Tidak termasuk listrik        20.0           Yes  Yes  Yes   Yes
# 4  Tidak termasuk listrik        16.0           Yes  Yes  Yes   Yes
#
#   Akses 24 Jam  Panjang Kamar  Lebar Kamar  \
# 0          Yes            2.0          2.5
# 1          Yes            2.0          2.5
# 2          Yes            2.0          3.0
# 3          Yes            5.0          4.0
# 4          Yes            4.0          4.0
#
#                                                 Maps  Latitude  Longitude
# 0  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 1  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 2  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 3  https://maps.google.com/maps?z=7&q=-7.319905,1... -7.319905  112.79770
# 4  https://maps.google.com/maps?z=7&q=-7.319905,1... -7.319905  112.79770

# %%
df["Longitude"]
# Out:
# 0      112.774090
# 1      112.774090
# 2      112.774090
# 3      112.797700
# 4      112.797700
#           ...
# 672    112.806338
# 673    112.786996
# 674    112.808134
# 675    112.803380
# 676    112.803380
# Name: Longitude, Length: 677, dtype: float64

# %% [markdown]
# `Menghitung jarak lokasi kos terhadap kampus UPN (dalam km)`

# %%
# Data kampus dan koordinatnya
kampus_data = {
    'UPN': (-7.3327844081176625, 112.7886245733404)
}

kampus_data
# Out:
# {'UPN': (-7.3327844081176625, 112.7886245733404)}

# %%
from math import radians, sin, cos, atan2, sqrt

# Fungsi untuk menghitung jarak Haversine
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Radius bumi dalam kilometer
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])  # Konversi derajat ke radian
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance

# %% [markdown]
# Tujuan dari baris kode ini adalah untuk menghitung jarak dari setiap lokasi kos-kosan ke setiap kampus yang ada, menggunakan fungsi haversine yang telah kita definisikan sebelumnya. Hasil perhitungan ini akan ditambahkan sebagai kolom baru di DataFrame dengan nama kampus yang bersangkutan.

# %%
# Menghitung jarak ke kampus dan menambahkannya ke DataFrame
for kampus, coords in kampus_data.items():
    df[kampus] = df.apply(lambda row: haversine(row['Latitude'], row['Longitude'], coords[0], coords[1]), axis=1)

# %%
df.head()
# Out:
#                                                 Link  \
# 0  https://mamikos.com/room/kost-kota-surabaya-ko...
# 1  https://mamikos.com/room/kost-kota-surabaya-ko...
# 2  https://mamikos.com/room/kost-kota-surabaya-ko...
# 3  https://mamikos.com/room/kost-kota-surabaya-ko...
# 4  https://mamikos.com/room/kost-kota-surabaya-ko...
#
#                                                 Nama   Lokasi    Harga  Jenis  \
# 0  Kost Singgahsini Rungkut Asri Utara XI Tipe C ...  Rungkut   880000  Putri
# 1  Kost Singgahsini Rungkut Asri Utara XI Tipe A ...  Rungkut  1275000  Putri
# 2  Kost Singgahsini Rungkut Asri Utara XI Tipe B ...  Rungkut   925000  Putri
# 3  Kost Singgahsini Rabbani Syariah Tipe A Rungku...  Rungkut  2525000  Putri
# 4  Kost Singgahsini Rabbani Syariah Tipe C Rungku...  Rungkut  2025000  Putri
#
#                   Listrik  Luas Kamar K Mandi Dalam   AC WiFi Kasur  \
# 0  Tidak termasuk listrik         5.0            No   No  Yes   Yes
# 1  Tidak termasuk listrik         5.0            No  Yes  Yes   Yes
# 2  Tidak termasuk listrik         6.0            No   No  Yes   Yes
# 3  Tidak termasuk listrik        20.0           Yes  Yes  Yes   Yes
# 4  Tidak termasuk listrik        16.0           Yes  Yes  Yes   Yes
#
#   Akses 24 Jam  Panjang Kamar  Lebar Kamar  \
# 0          Yes            2.0          2.5
# 1          Yes            2.0          2.5
# 2          Yes            2.0          3.0
# 3          Yes            5.0          4.0
# 4          Yes            4.0          4.0
#
#                                                 Maps  Latitude  Longitude  \
# 0  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 1  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 2  https://maps.google.com/maps?z=7&q=-7.3232453,... -7.323245  112.77409
# 3  https://maps.google.com/maps?z=7&q=-7.319905,1... -7.319905  112.79770
# 4  https://maps.google.com/maps?z=7&q=-7.319905,1... -7.319905  112.79770
#
#         UPN
# 0  1.922106
# 1  1.922106
# 2  1.922106
# 3  1.747229
# 4  1.747229

# %%
df.to_csv("data_hasil_ekstrak_maps.csv", index=True)
